# %%
# https://pypi.org/project/opencv-python/
# https://pypi.org/project/pyzbar/
import pyzbar.pyzbar as pyzbar
import cv2
import matplotlib.pyplot as plt

# %%
qr=cv2.imread('./qr_1.png')
plt.imshow(qr)

# %%
qr_gray=cv2.cvtColor(qr, cv2.COLOR_BGR2GRAY)
plt.imshow(qr_gray, cmap='gray')

# %%
decoded=pyzbar.decode(qr_gray)
decoded
# Out:
# [Decoded(data=b'QR Code Generator by TEC-IT', type='QRCODE', rect=Rect(left=2, top=1, width=220, height=222), polygon=[Point(x=2, y=2), Point(x=2, y=221), Point(x=222, y=223), Point(x=222, y=1)])]

# %%
for d in decoded:
    print(d.data.decode('utf-8'))
    print(d.type)
# Out:
# QR Code Generator by TEC-IT
# QRCODE
