# %%
# https://pypi.org/project/opencv-python/
# https://pypi.org/project/pyzbar/
import pyzbar.pyzbar as pyzbar
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread('./bar_1.jpg')
plt.imshow(img)

# %%
gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')

# %%
decoded=pyzbar.decode(gray)
decoded
# Out:
# [Decoded(data=b'8992772485012', type='EAN13', rect=Rect(left=69, top=0, width=594, height=240), polygon=[Point(x=69, y=1), Point(x=69, y=239), Point(x=375, y=240), Point(x=663, y=240), Point(x=663, y=0)])]

# %%
for d in decoded:
    print(d.data.decode('utf-8'))
    print(d.type)
# Out:
# 8992772485012
# EAN13
