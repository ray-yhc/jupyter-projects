# %%
import import_ipynb
from instagram.libs.crawler import crawl
url="https://www.instagram.com/?hl=ko"
print(crawl(url))
# Out:
# <Response [200]> https://www.instagram.com/?hl=ko
# ...

# %%
# Out:
# importing Jupyter notebook from /workspace/python/crawling task/instagram/libs/crawler.ipynb
# <Response [200]> https://www.instagram.com/?hl=ko
# ...
